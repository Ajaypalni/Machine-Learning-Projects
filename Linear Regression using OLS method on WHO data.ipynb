# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
lyf_exp = pd.read_csv(r"C:/Users/DELL/Desktop/data/Life Expectancy Data.csv")

# %%
lyf_exp.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Country                                0
# Year                                   0
# Status                                 0
# Life expectancy                       50
# Adult Mortality                       50
# infant deaths                          0
# Alcohol                            15065
# percentage expenditure                 0
# Hepatitis B                        43806
# Measles                                0
#  BMI                                2218
# under-five deaths                      0
# Polio                               1198
# Total expenditure                  17778
# Diphtheria                          1198
#  HIV/AIDS                              0
# GDP                                35289
# Population                         51560
#  thinness  1-19 years               2218
#  thinness 5-9 years                 2218
# Income composition of resources    12835
# Schooling                          12815
# Disease                                0
# Value                                  0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233682 entries, 0 to 233681
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Country                          233682 non-null  object
#  1   Year                             233682 non-null  int64
#  2   Status                           233682 non-null  object
#  3   Life expectancy                  233682 non-null  float64
#  4   Adult Mortality                  233682 non-null  float64
#  5   infant deaths                    233682 non-null  int64
#  6   Alcohol                          233682 non-null  float64
#  7   percentage expenditure           233682 non-null  float64
#  8   Hepatitis B                      233682 non-null  float64
#  9   Measles                          233682 non-null  int64
#  10   BMI                             233682 non-null  float64
#  11  under-five deaths                233682 non-null  int64
#  12  Polio                            233682 non-null  float64
#  13  Total expenditure                233682 non-null  float64
#  14  Diphtheria                       233682 non-null  float64
#  15   HIV/AIDS                        233682 non-null  float64
#  16  GDP                              233682 non-null  float64
#  17  Population                       233682 non-null  float64
#  18   thinness  1-19 years            233682 non-null  float64
#  19   thinness 5-9 years              233682 non-null  float64
#  20  Income composition of resources  233682 non-null  float64
#  21  Schooling                        233682 non-null  float64
#  22  Disease                          233682 non-null  object
#  23  Value                            233682 non-null  float64
# dtypes: float64(17), int64(4), object(3)
# memory usage: 44.6+ MB

# %%
df['Status'].value_counts()
# Out:
# Developing    192722
# Developed      40960
# Name: Status, dtype: int64

# %%
varlist = ['Status']

def binary_map(x):
    return x.map({"Developing":1,"Developed":0})
df[varlist]= df[varlist].apply(binary_map)

# %%
df.head()
# Out:
#        Country  Year  Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015       1              65.0            263.0
# 1  Afghanistan  2015       1              65.0            263.0
# 2  Afghanistan  2015       1              65.0            263.0
# 3  Afghanistan  2015       1              65.0            263.0
# 4  Afghanistan  2015       1              65.0            263.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             62     0.01               71.279624         65.0      1154  ...
# 2             62     0.01               71.279624         65.0      1154  ...
# 3             62     0.01               71.279624         65.0      1154  ...
# 4             62     0.01               71.279624         65.0      1154  ...
#
#    Diphtheria    HIV/AIDS        GDP  Population   thinness  1-19 years  \
# 0         65.0        0.1  584.25921  33736494.0                   17.2
# 1         65.0        0.1  584.25921  33736494.0                   17.2
# 2         65.0        0.1  584.25921  33736494.0                   17.2
# 3         65.0        0.1  584.25921  33736494.0                   17.2
# 4         65.0        0.1  584.25921  33736494.0                   17.2
#
#     thinness 5-9 years  Income composition of resources  Schooling    Disease  \
# 0                 17.3                            0.479       10.1   HIV/AIDS
# 1                 17.3                            0.479       10.1   HIV/AIDS
# 2                 17.3                            0.479       10.1   HIV/AIDS
# 3                 17.3                            0.479       10.1   HIV/AIDS
# 4                 17.3                            0.479       10.1   HIV/AIDS
#
#    Value
# 0    0.1
# 1    0.1
# 2    0.1
# 3    0.1
# 4    0.1
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233682 entries, 0 to 233681
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Country                          233682 non-null  object
#  1   Year                             233682 non-null  int64
#  2   Status                           233682 non-null  int64
#  3   Life expectancy                  233682 non-null  float64
#  4   Adult Mortality                  233682 non-null  float64
#  5   infant deaths                    233682 non-null  int64
#  6   Alcohol                          233682 non-null  float64
#  7   percentage expenditure           233682 non-null  float64
#  8   Hepatitis B                      233682 non-null  float64
#  9   Measles                          233682 non-null  int64
#  10   BMI                             233682 non-null  float64
#  11  under-five deaths                233682 non-null  int64
#  12  Polio                            233682 non-null  float64
#  13  Total expenditure                233682 non-null  float64
#  14  Diphtheria                       233682 non-null  float64
#  15   HIV/AIDS                        233682 non-null  float64
#  16  GDP                              233682 non-null  float64
#  17  Population                       233682 non-null  float64
#  18   thinness  1-19 years            233682 non-null  float64
#  19   thinness 5-9 years              233682 non-null  float64
#  20  Income composition of resources  233682 non-null  float64
#  21  Schooling                        233682 non-null  float64
#  22  Disease                          233682 non-null  object
#  23  Value                            233682 non-null  float64
# dtypes: float64(17), int64(5), object(2)
# memory usage: 44.6+ MB

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(),cmap='crest',annot=True)
plt.show()

# %%
df.drop(['under-five deaths ','Disease','Value','Country'], axis=1, inplace=True)

# %%
X = df.drop(['Life expectancy '],axis=1)
y= df['Life expectancy ']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# # Model 1

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# -43.366543585550346
# [ 5.25478083e-02 -2.93562063e+00 -2.14085280e-02 -8.86161979e-04
#   1.46084703e-01  3.21744067e-05  6.52346974e-03 -2.04928221e-05
#   6.25818459e-02  3.38401268e-02 -3.92244348e-03  3.76467436e-02
#  -4.95422493e-01  4.63069768e-05  2.23447529e-09 -1.53068133e-01
#   2.40488270e-02  4.30788952e+00  2.14949485e-01]

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
r_squared = r2_score(y_test,y_pred)

# %%
r_squared
# Out:
# 0.7730581083617333

# %% [markdown]
# # Model 2

# %%
import statsmodels.api as sm
X_train_sm = sm.add_constant(X_train)
lr = sm.OLS(y_train,X_train_sm).fit()

# %%
lr.params
# Out:
# const                             -4.336654e+01
# Year                               5.254781e-02
# Status                            -2.935621e+00
# Adult Mortality                   -2.140853e-02
# infant deaths                     -8.861619e-04
# Alcohol                            1.460847e-01
# percentage expenditure             3.217441e-05
# Hepatitis B                        6.523470e-03
# Measles                           -2.049282e-05
#  BMI                               6.258185e-02
# Polio                              3.384013e-02
# Total expenditure                 -3.922443e-03
# Diphtheria                         3.764674e-02
#  HIV/AIDS                         -4.954225e-01
# GDP                                4.630698e-05
# Population                         2.234475e-09
#  thinness  1-19 years             -1.530681e-01
#  thinness 5-9 years                2.404883e-02
# Income composition of resources    4.307890e+00
# Schooling                          2.149495e-01
# dtype: float64

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Life expectancy    R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                 2.891e+04
# Date:                Mon, 11 Sep 2023   Prob (F-statistic):               0.00
# Time:                        20:56:10   Log-Likelihood:            -4.8106e+05
# No. Observations:              163577   AIC:                         9.622e+05
# Df Residuals:                  163557   BIC:                         9.624e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                             -43.3665      5.516     -7.862      0.000     -54.177     -32.556
# Year                                0.0525      0.003     19.121      0.000       0.047       0.058
# Status                             -2.9356      0.040    -73.002      0.000      -3.014      -2.857
# Adult Mortality                    -0.0214      0.000   -178.044      0.000      -0.022      -0.021
# infant deaths                      -0.0009      0.000     -6.265      0.000      -0.001      -0.001
# Alcohol                             0.1461      0.004     38.765      0.000       0.139       0.153
# percentage expenditure           3.217e-05   1.39e-05      2.309      0.021    4.86e-06    5.95e-05
# Hepatitis B                         0.0065      0.000     17.407      0.000       0.006       0.007
# Measles                         -2.049e-05   1.15e-06    -17.774      0.000   -2.28e-05   -1.82e-05
#  BMI                                0.0626      0.001     85.775      0.000       0.061       0.064
# Polio                               0.0338      0.001     50.429      0.000       0.033       0.035
# Total expenditure                  -0.0039      0.005     -0.871      0.384      -0.013       0.005
# Diphtheria                          0.0376      0.001     53.894      0.000       0.036       0.039
#  HIV/AIDS                          -0.4954      0.003   -184.646      0.000      -0.501      -0.490
# GDP                              4.631e-05   2.09e-06     22.190      0.000    4.22e-05    5.04e-05
# Population                       2.234e-09   2.54e-10      8.809      0.000    1.74e-09    2.73e-09
#  thinness  1-19 years              -0.1531      0.008    -20.232      0.000      -0.168      -0.138
#  thinness 5-9 years                 0.0240      0.007      3.222      0.001       0.009       0.039
# Income composition of resources     4.3079      0.096     45.024      0.000       4.120       4.495
# Schooling                           0.2149      0.006     38.412      0.000       0.204       0.226
# ==============================================================================
# Omnibus:                    53195.431   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1394876.408
# Skew:                          -0.993   Prob(JB):                         0.00
# Kurtosis:                      17.167   Cond. No.                     2.67e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.67e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
